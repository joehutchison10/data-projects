# %%
import pandas as pd
import numpy as np

diabetes_data = pd.read_csv("diabetes.csv")

# %%
print(diabetes_data.head(10))
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age Outcome
# 0                     0.627   50       1
# 1                     0.351   31       0
# 2                     0.672   32       1
# 3                     0.167   21       0
# 4                     2.288   33       1
# 5                     0.201   30       0
# 6                     0.248   26       1
# 7                     0.134   29       0
# 8                     0.158   53       1
# 9                     0.232   54       1

# %%
#to find out if any columns is missing data
print(diabetes_data.isnull().sum())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#another method to see if data is missing any values, which finds minimums of 0 (missing data) for variables, and questionable maximums e.g 17 for pregnancy 
print(diabetes_data.describe())
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  768.000000                768.000000  768.000000
# mean    31.992578                  0.471876   33.240885
# std      7.884160                  0.331329   11.760232
# min      0.000000                  0.078000   21.000000
# 25%     27.300000                  0.243750   24.000000
# 50%     32.000000                  0.372500   29.000000
# 75%     36.600000                  0.626250   41.000000
# max     67.100000                  2.420000   81.000000

# %%
#replaces instances of 0 with NaN, to exclude these values from our summary statistics 
diabetes_data[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']] = diabetes_data[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(0,np.nan)

# %%
#prints rows which have missing (null) values. Every row with at least one missing value, has a missing value in the insulin column

print(diabetes_data[diabetes_data.isnull().any(axis=1)])
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0      NaN  33.6
# 1              1     85.0           66.0           29.0      NaN  26.6
# 2              8    183.0           64.0            NaN      NaN  23.3
# 5              5    116.0           74.0            NaN      NaN  25.6
# 7             10    115.0            NaN            NaN      NaN  35.3
# ..           ...      ...            ...            ...      ...   ...
# 761            9    170.0           74.0           31.0      NaN  44.0
# 762            9     89.0           62.0            NaN      NaN  22.5
# 764            2    122.0           70.0           27.0      NaN  36.8
# 766            1    126.0           60.0            NaN      NaN  30.1
# 767            1     93.0           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age Outcome
# 0                       0.627   50       1
# 1                       0.351   31       0
# 2                       0.672   32       1
# 5                       0.201   30       0
# 7                       0.134   29       0
# ..                        ...  ...     ...
# 761                     0.403   43       1
# 762                     0.142   33       0
# 764                     0.340   27       0
# 766                     0.349   47       1
# 767                     0.315   23       0
#
# [376 rows x 9 columns]

# %%
#Making sure columns are expected data types 
print(diabetes_data.dtypes)
#Determining why Outcome column is an object type instead of int64, which appears to be caused by inputs of "O" instead of "0"
print(diabetes_data.Outcome.unique())
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                      object
# dtype: object
# ['1' '0' 'O']

# %%
# Replace 'O' with 0 in the Outcome column
diabetes_data['Outcome'] = diabetes_data['Outcome'].replace('O', 0)

# Convert the Outcome column to int64
diabetes_data['Outcome'] = diabetes_data['Outcome'].astype('int64')

# %%
#now we have cleaned the data, we can predict the probability of one being diabetic, given their BMI 

import statsmodels.api as sm
import matplotlib.pyplot as plt 

#we can use logistic regression to do this, since we have a binary variable (outcome for diabetes) and a continious variable (BMI). 
#this model shows that for each unit increase in BMI, the probability that one is diabetic increases by 0.09! (Z = 7.6, very sig!)

X = diabetes_data[["BMI"]]
X = sm.add_constant(X)
Y = diabetes_data["Outcome"]
model =sm.Logit(Y, X)
result = model.fit()
print(result.summary())


#lets plot our model on a graph, so we can clearly see the relationship 

x_vals = np.linspace(diabetes_data["BMI"].min(), diabetes_data["BMI"].max(), 100)
X_plot = pd.DataFrame({"intercept": 1, "BMI": x_vals})
y_vals = result.predict(X_plot)


plt.scatter(diabetes_data["BMI"], diabetes_data["Outcome"], label = "Actual Data")
plt.plot(x_vals, y_vals, color = "red", label = "Logistic fit")
plt.xlabel("BMI")
plt.ylabel("Probability of Diabetes")
plt.legend()
plt.title("Logistic Regression Curve")
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.599423
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Outcome   No. Observations:                  768
# Model:                          Logit   Df Residuals:                      766
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 30 Apr 2025   Pseudo R-squ.:                 0.07325
# Time:                        10:28:15   Log-Likelihood:                -460.36
# converged:                       True   LL-Null:                       -496.74
# Covariance Type:            nonrobust   LLR p-value:                 1.457e-17
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.6864      0.409     -9.014      0.000      -4.488      -2.885
# BMI            0.0935      0.012      7.761      0.000       0.070       0.117
# ==============================================================================

# %%
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.4-cp312-cp312-win_amd64.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\joe hutchison\miniconda3\lib\site-packages (from statsmodels) (2.2.3)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\joe hutchison\miniconda3\lib\site-packages (from statsmodels) (1.15.2)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\joe hutchison\miniconda3\lib\site-packages (from statsmodels) (2.2.3)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\joe hutchison\miniconda3\lib\site-packages (from statsmodels) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\joe hutchison\miniconda3\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\joe hutchison\miniconda3\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\joe hutchison\miniconda3\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\joe hutchison\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Downloading statsmodels-0.14.4-cp312-cp312-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.8 MB 3.4 MB/s eta 0:00:03
#    -------- ------------------------------- 2.1/9.8 MB 4.9 MB/s eta 0:00:02
#    ------------ --------------------------- 3.1/9.8 MB 5.0 MB/s eta 0:00:02
#    ------------------ --------------------- 4.5/9.8 MB 5.4 MB/s eta 0:00:01
#    ------------------------ --------------- 6.0/9.8 MB 5.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.3/9.8 MB 5.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.7/9.8 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 5.8 MB/s eta 0:00:00
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-1.0.1 statsmodels-0.14.4
